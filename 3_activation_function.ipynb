# %% [markdown]
# # Activation Function

# %%
import torch
import torch.nn.functional as f
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %matplotlib inline

x = torch.linspace(-5, 5, 200) # a tensor contains 200 values from -5 to 5
x = Variable(x)
x_np = x.data.numpy() # numpy array used for matplotlib

y_relu = torch.relu(x).data.numpy()
y_sigmoid = torch.sigmoid(x).data.numpy()
y_tanh = torch.tanh(x).data.numpy()
y_softplus = f.softplus(x).data.numpy()

# %%
plt.figure(1, figsize=(8, 6))
plt.subplot(221)
plt.plot(x_np, y_relu, c='blue', label='relu')
plt.ylim(-1, 5)
plt.legend(loc='best')


plt.subplot(222)
plt.plot(x_np, y_sigmoid, c='blue', label='sigmoid')
plt.ylim(-0.2, 1.2)
plt.legend(loc='best')

plt.subplot(223)
plt.plot(x_np, y_tanh, c='blue', label='tanh')
plt.ylim(-1.2, 1.2)
plt.legend(loc='best')


plt.subplot(224)
plt.plot(x_np, y_softplus, c='blue', label='softplus')
plt.ylim(-0.2, 6)
plt.legend(loc='best')
